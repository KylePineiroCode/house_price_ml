# %% [markdown]
# # **House Price Model**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# The prediction of property prices is becoming increasingly important and beneficial. Property prices are a good indicator of both overall market condition and the economic health of a country. The dataset we are working on is house prices through the entire United States. Prices may vary depending on siz
